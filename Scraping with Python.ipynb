# %% [markdown]
# # Session 4: Python Web Scraping

# %%
import urllib.request
import urllib.parse
import re
import requests
from bs4 import BeautifulSoup
from collections import Counter
from string import punctuation

# %%
url = 'http://www.crummy.com/software/BeautifulSoup'
soup = BeautifulSoup(respdata, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN"
# "http://www.w3.org/TR/REC-html40/transitional.dtd">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Beautiful Soup: We called him Tortoise because he taught us.
#   </title>
#   <link href="mailto:leonardr@segfault.org" rev="made"/>
#   <link href="/nb/themes/Default/nb.css" rel="stylesheet" type="text/css"/>
#   <meta content="Beautiful Soup: a library designed for screen-scraping HTML and XML." name="Description"/>
#   <meta content="Markov Approximation 1.4 (module: leonardr)" name="generator"/>
#   <meta content="Leonard Richardson" name="author"/>
#  </head>
#  <body alink="red" bgcolor="white" link="blue" text="black" vlink="660066">
#   <img align="right" src="10.1.jpg" width="250"/>
#   <br/>
#   <p>
#    You didn't write that awful page. You're just trying to get some
# data out of it. Beautiful Soup is here to help. Since 2004, it's been
# ...

# %%
r = requests.get(url)
soup = BeautifulSoup(r.content)
req=urllib.request.Request(url)
resp=urllib.request.urlopen(req)
respdata=resp.read()
soup = BeautifulSoup(respdata)

text = (' '.join(s.findAll(text=True))for s in soup.find_all())

c = Counter((x.rstrip(punctuation).lower() for y in text for x in y.split()))
# Out:
# /home/winta/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/winta/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print (c. most_common())
# Out:
# [('the', 125), ('', 121), ('beautiful', 120), ('soup', 120), ('to', 90), ('of', 64), ('a', 63), ('and', 63), ('you', 61), ('is', 45), ('python', 40), ('it', 39), ('in', 32), ('on', 30), ('3', 28), ('or', 25), ('for', 22), ('document', 21), ('can', 21), ('all', 20), ('under', 20), ('uses', 20), ('projects', 18), ('download', 16), ('source', 16), ('time', 16), ('beautifulsoup', 16), ('if', 15), ('about', 15), ('have', 15), ('as', 15), ('license', 15), ('leonard', 15), ('richardson', 15), ('discussion', 14), ('group', 14), ('i', 14), ('software', 14), ('tree', 14), ('text', 14), ('install', 14), ('licensed', 14), ('crummy', 14), ('me', 13), ('that', 12), ('from', 12), ('an', 12), ('unless', 12), ('"find', 12), ('was', 12), ('last', 12), ('nowhere', 12), ('standard', 12), ('been', 11), ('what', 11), ('code', 11), ('hall', 10), ('fame', 10), ('development', 10), ('like', 10), ('used', 10), ("it's", 9), ('documentation', 9), ('zine', 9), ('find', 9), ('bug', 9), ('file', 9), ('parse', 9), 
# ...

# %%
soup.title
# Out:
# <title>Beautiful Soup: We called him Tortoise because he taught us.</title>

# %%
print ([i for i in c if c.get(i) > 10]) # words appearing more than 10 times
# Out:
# ['beautiful', 'soup', 'you', 'that', 'to', 'of', 'it', 'is', 'been', 'or', 'on', 'projects', '', 'download', 'source', 'discussion', 'group', 'if', 'a', 'time', 'and', 'me', 'i', 'about', 'what', 'software', 'from', 'have', 'the', 'python', 'for', 'tree', 'document', 'code', 'an', 'unless', 'can', '"find', 'all', 'text', 'was', 'in', 'install', 'as', '3', 'licensed', 'under', 'license', 'beautifulsoup', 'uses', 'crummy', 'leonard', 'richardson', 'last', 'nowhere', 'standard']

# %%
print("Is the word 'Alice' mentioned on the beautiful soup homepage?", c.get('Alice'))
print(" The word 'Soup' occur on the site",c.get('soup'))
# Out:
# Is the word 'Alice' mentioned on the beautiful soup homepage? None
#  The word 'Soup' occur on the site 120
